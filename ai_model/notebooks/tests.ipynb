# %%
import os

# %%
folder_path = r"D:\AI-Driven-Call-Center-Issue-Analysis-System---FYP\ai_model\data\limited_wav_files\limited_wav_files"
files = os.listdir(folder_path)

print(f"Total files found: {len(files)}")
print("First 5 files:", files[:5])  # Show first few files
# Out:
# Total files found: 20000
# First 5 files: ['common_voice_ur_26562732.wav', 'common_voice_ur_26562733.wav', 'common_voice_ur_26562734.wav', 'common_voice_ur_26562735.wav', 'common_voice_ur_26562736.wav']

# %%
import librosa

# %%
print(librosa.__version__)
# Out:
# 0.10.2.post1

# %%
import os

features_path = r"E:\AI-Driven-Call-Center-Issue-Analysis-System---FYP\ai_model\data\processed_data\audio_features.npy"
file_size = os.path.getsize(features_path) / (1024 * 1024)  # Convert bytes to MB

print(f"File Size: {file_size:.2f} MB")
# Out:
# File Size: 0.77 MB

# %%
import numpy as np

features = np.load(features_path)

print(f"Shape of extracted features: {features.shape}")
# Out:
# Shape of extracted features: (10, 128, 157)

# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.1 MB 10.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.1 MB 12.9 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 13.0 MB/s eta 0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 13.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 13.3 MB/s eta 0:00:00
# Using cached pyparsing-3.2.1-py3-none-any.whl (107 kB)
# ...

# %%
from matplotlib import pyplot as plt 

plt.figure(figsize=(10, 4))
plt.imshow(features[0], aspect='auto', origin='lower')
plt.colorbar()
plt.title("Log-Mel Spectrogram of First Audio")
plt.show()

# %%
if np.any(features):  # Check if all values are zero
    print("Feature extraction looks good")
else:
    print("All extracted features are zero! Something went wrong.")
# Out:
# Feature extraction looks good! 🎉

# %%
import os

features_path = r"E:\AI-Driven-Call-Center-Issue-Analysis-System---FYP\ai_model\data\processed_data\audio_features.npy"
file_size = os.path.getsize(features_path) / (1024 * 1024)  # Convert bytes to MB

print(f"File Size: {file_size:.2f} MB")
# Out:
# File Size: 1533.20 MB

# %%
from matplotlib import pyplot as plt 

data = np.load(features_path)
plt.imshow(data[19000], aspect='auto', origin='lower')
plt.colorbar()
plt.title("Log-Mel Spectrogram of First Audio")
plt.show()
